# %% [markdown]
# <a href="https://colab.research.google.com/github/myaorina/DATA-SCIENCE-SC/blob/main/DAY_1_PYTHON_INTRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INTRODUCTION TO PYTHON:FIRST PIECE OF CODE
# Syntax-Rules of writing code in a given language
# Don't start functions with capital letters ie. Print instead of print
# All text(strings) should be enclosed in quotations
# Strings- Text within quotations(you can use either double or single but double quotations are preferred)
# Text without quotation is not considered a string
# Hardcoding is when you're not using variables
# **Variables are used to store data**
# =(single equal signs) are referred to as assignment operators which are special characters that have a given use within python
# to run you can press"Shift+enter"
# To combine words or values or two lines use a comma which in simple terms is like a blank space
# Don't enclose varibles in quotation marks
# You can use curly braces to enclose variables while using f string
# There shouldn't be any space between variables while naming hence should be combined using an underscore majorly used for variable names(this case is referred to as snake case) ie, first_name or you may use capitalisation majorly used for function names(referred to as the camel case) ie,FirstName.
# Don't start variables with numbers but you can have numbers in between or at the end of the variable names
# Only underscores are allowed within variable naming so hyphens,plus,asterisk among other special characters aren't allowed
# Underscores are mostly used at the start of a variable in object oriented programming
# Red wavy line usually signifies syntax errors
# ^(up facing carat) shows where the error is likely to be

# %%
print(10)
# Out:
# 10

# %%
Current_year =  2026
Birth_year = 2007

Age= Current_year-Birth_year
print(Age)
# Out:
# 19

# %%
name = "Mya"
name = "Orina"
print(name)
# Out:
# Orina

# %%
print("I am 19 years old")
# Out:
# I am 19 years old

# %%
print("my hobby is swimming")
# Out:
# my hobby is swimming

# %%
print("my name is Mya")
# Out:
# my name is Mya

# %%
print("2fa")
# Out:
# 2fa

# %%
name = "Mya"
print(name)
# Out:
# Mya

# %%
names = "mya"
names = "orina"
print(names)
# Out:
# orina

# %%
name = "John"
print("my name is",name)
# Out:
# my name is John
