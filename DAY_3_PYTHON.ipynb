# %% [markdown]
# <a href="https://colab.research.google.com/github/myaorina/DATA-SCIENCE-SC/blob/main/DAY_3_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DAY 3 PYTHON:DECISION MAKING WITH PYTHON
# True or False are only considered boolean when they start with a capital letter.....***so is it possible to use the two words as maybe variables if written entirely in lowercase?***
# (!=) stands for inequality
# If statements are used for decision making
# in if statements you have to input a full colon after the condition ,failure to which the body will not be indented so you'd have to do it yourself
# The full colon must be present after the condition
# It is more advisable to use tabs instead of spaces while indenting for consistency purposes wherein if you have 2 spaces in a line and 3 in another an error will be detected due to inconsistency/non-uniform indentation
# Only the body is indented
# for multiple choices use elif
# as many elifs as required can be used with the last condition being an else
# elif is the same as else if
# Logic error-error that occurs when you get
# prompting is asking for input from a user while hard coding is without asking for outside input but using fixed data
# Concatenation-Combining

# %% [markdown]
# How to make it 2dp

# %% [markdown]
# The program that you create for this exercise will begin by reading the cost of a meal
# ordered at a restaurant from the user. Then your program will compute the tax and
# tip for the meal. Use your local tax rate when computing the amount of tax owing.
# Compute the tip as 18 percent of the meal amount (without the tax). The output from
# your program should include the tax amount, the tip amount, and the grand total for
# the meal including both the tax and the tip. Format the output so that all of the values
# are displayed using two decimal places.
#
# *Always type cast and use f string as is more convenient
# In the event that you use the other method nothing bad will happen but fixing the error might be a little hectic because the syntax errors may be a lot more hidden than you expect.

# %%
cost = input("How much was your meal?")
cost_1 = float(cost)

tip_amount= (cost_1*0.1)
tax_amount= (cost_1*0.18)
grand_total=(cost_1+tip_amount+tax_amount)

print(f"The tax amount will be Ksh.{tax_amount:.5f}")
print(f"The tip amount will be Ksh.{tip_amount:.2f}")
print(f"The grand total will be Ksh.{grand_total:.3f}")
# Out:
# How much was your meal?456.879
# The tax amount will be Ksh.82.23822
# The tip amount will be Ksh.45.69
# The grand total will be Ksh.584.805

# %% [markdown]
# How to make sure someone enters a positive integer

# %% [markdown]
# GET A NESTED IF QUESTION ON PYTHON AND SOLVE IT AS ASSIGNMENT!!!

# %% [markdown]
# Write a program that reads a positive integer, n, from the user and then displays the
# sum of all of the integers from 1 to n. The sum of the first n positive integers can be
# computed using the formula:
# sum = (n)(n +1

# %%
n= input("Please input a positive integer:")
n=int(n)

sum= int((n*(n+1))/2)
print(f"The sum of the first {n} positive integers is {sum}")
# Out:
# Please input a positive integer:5
# The sum of the first 5 positive integers is 15

# %% [markdown]
# An online retailer sells two products: widgets and gizmos. Each widget weighs 75
# grams. Each gizmo weighs 112 grams. Write a program that reads the number of
# widgets and the number of gizmos in an order from the user. Then your program
# should compute and display the total weight of the order

# %%
widgets=input("How many widgets are there?")
gizmos=input("How many gizmos are there?")

number_of_widgets=float(widgets)
number_of_gizmos=float(gizmos)

gizmos_weight= number_of_gizmos*112
widgets_weight= number_of_widgets*75

total_order_weight = gizmos_weight + widgets_weight


print("Number of widgets:",number_of_widgets)
print("Number of gizmos:",number_of_gizmos)
print(f"The total weight of the order is:{total_order_weight}kgs")
# Out:
# How many widgets are there?45
# How many gizmos are there?90
# Number of widgets: 45.0
# Number of gizmos: 90.0
# The total weight of the order is:13455.0kgs

# %% [markdown]
# What specific cases is the word not or exclamation mark used?or rather are there specicfc cases where either of the two cannot be used or would lead to an error?

# %%
is_raining = False
if is_raining:
  print("Stay indoors")

if not is_raining:
  print("go out")
# Out:
# go out

# %% [markdown]
# ***MONEY WITHDRAWAL***

# %%
balance=500
withdraw_amount=float(input("How much would you like to withdraw?"))

if withdraw_amount>balance:
  print("You have insufficient balance")
  print("Tap and try again")


if withdraw_amount<balance:
  print("Succesful withdrawal")
# Out:
# How much would you like to withdraw?578
# You have insufficient balance
# Tap and try again

# %%
student_score= int(input("What was your entry score? "))

if student_score>=50:
  print("Great work,keep it up")

if student_score<50:
  print("Work on your weak areas")
# Out:
# What was your entry score? 67
# Great work,keep it up

# %% [markdown]
# ***PASSWORD*** ***CHECKER***

# %%
password=input("Input password")

if password=="python123":
  print("Entry granted")

else:
  print("access denied")
# Out:
# Input passwordpython123
# Entry granted

# %%
name=input("Name? ")

if name== "Mya":
  print("Smart")

else:
  print("Nahh bruh")
# Out:
# Name?Mya
# Smart

# %% [markdown]
# First one has to be false for the second to be answered so only one answer is given
#
# Else is only applicable to the latter or rather immediate preceeding if

# %%
is_raining=input("If raining,type 1. If not,type 2. ")
is_cloudy=input("if cloudy,type 1. If not,type 2. ")

if is_raining =="1":
  print("Use an umbrella")

elif is_cloudy =="1":
  print("carry an umbrella")

else:
  print("Umbrella not required")
# Out:
# If raining,type 1. If not,type 2. 1
# if cloudy,type 1. If not,type 2. 1
# Use an umbrella

# %% [markdown]
# ***GRADE INPUT SYSTEM***

# %%
grade= input("Enter your grade: ")

if grade == "A":
  print("You scored above 80")

elif grade =="B":
  print("You scored between 71 and 80")

elif grade =="C":
  print("You scored between 61 and 70")

elif grade =="D":
  print("You scored between 51 and 60")

elif grade =="E":
  print("You scored between 41 and 50")

elif grade =="F":
  print("You scored less than 41")

else:
  print("Invalid input")
# Out:
# Enter your grade: C
# You scored between 61 and 70

# %% [markdown]
# For ***or*** as long as one of the conditions is true then the entire evaluation is true
#
# For ***and*** everything needs to be true for the final evaluation to be true

# %%
a=1
b=2
c=3
print(a==b and b==c)
print(a<b or b>c)
print(a<b and b>c)
# Out:
# False
# True
# False

# %% [markdown]
# Regarding order of the if and elifs....start with the more specific ones down to the more general ones
# Modulus was a ket factor in the code below
# can also be used in a case study regarding even and odd numbers

# %%
value=int(input("Input value: "))

if value % 2 == 0 and value % 3== 0:
  print("Divisible by both 2 and 3.")

elif value % 2 == 0:
  print("Divisible by 2.")

elif value % 3== 0:
  print("Divisible by 3.")

else:
  print("Not divisible by 2 or 3.")
# Out:
# Input value: 4578
# Divisible by both 2 and 3.

# %% [markdown]
# CHAINED GRADING SYSTEM

# %%
score = int(input("Score: "))

if score >= 80:
  print("Grade A")

elif score >= 70:
  print("Grade B")

elif score >= 60:
  print("Grade C")

else:
  print("Grade F")
# Out:
# Score: 56
# Grade F

# %% [markdown]
# How to make it 2dp:(down arrow)
#
# Use f string and within the curly brackets,add(.2f then close the curly brackets together with the variable in question.
# if you want to make it 3,4 or 5 decimal places you replace the 2 in the formula with the specific number of decimal places you want respectively.

# %%
disposable_income=monthly_income-monthly_expenses
savings_rate=(disposable_income/monthly income)*100

print(f"Savings rate: {savings_rate:.2f}%")

# %% [markdown]
# ***WORKING WITH STRINGS IN PYTHON***

# %%
accent = "#" *5
print(accent) # Outputs: #####
# Out:
# #####

# %%
WORD = "PYTHON"
print(WORD[0]) # 'P'
print(WORD[-1]) # 'N'
# Out:
# P
# N

# %% [markdown]
# But fr though i will ask about the yesterday's strings session or at least for the notes
