# %% [markdown]
# <a href="https://colab.research.google.com/github/myaorina/DATA-SCIENCE-SC/blob/main/WEEK_2_DAY_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a program that computes the body mass index (BMI) of an individual.
# Your program should begin by reading a height and weight from the user.
# Then it should use one of the following two formulas to compute the BMI before displaying it.
# If you read the height in inches and the weight in pounds then body mass index is computed using the following formula:
# BMI =    weight    × 703.
#      height × height
# If you read the height in meters and the weight in kilograms then body mass index is computed using this slightly simpler formula:
# BMI =     weight
#      height × height

# %%
height = float(input("Enter your height in metres: "))
weight = float(input("Enter your weight in kilograms: "))

metrics= input("Type 1 if you used pounds/inches or metres/kilograms")

if metrics=="1":
   bmi = (weight / (height * height)) * 703
   print(f"Your body mass index is {bmi:.2f}")
elif metrics=="2":
   bmi = weight / (height * height)
   print(f"Your body mass index is {bmi:.2f}")

else:
  print("Invalid metrics")
# Out:
# Enter your height in metres: 56
# Enter your weight in kilograms: 45
# Type 1 if you used pounds/inches or metres/kilograms1
# Your body mass index is 10.09

# %%
units=input("Enter units used: ")

if units== "metres":
    height = float(input("Enter your height in metres: "))
    weight = float(input("Enter your weight in kilograms: "))
    bmi = weight / (height * height)

elif units== "inches":
    height = float(input("Enter your height in inches: "))
    weight = float(input("Enter your weight in pounds: "))
    bmi = (weight / (height * height)) * 703


print(f"Your body mass index is {bmi:.2f}")
# Out:
# Enter units used: 56
# Your body mass index is 10.09

# %% [markdown]
# Develop a program that reads a four-digit integer from the user and displays the sum of the digits in the number.45
#  For example, if the user enters 3141 then your program should display 3+1+4+1=9.

# %%
number=int(input("Enter a four digit number: "))

total =int((number[0]) + (number[1]) + (number[2]) + (number[3]))

print(f"{number[0]}+{number[1]}+{number[2]}+{number[3]}={total}")
# Out:
# Enter a four digit number: 4567
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_493/39268776.py in <cell line: 0>()
#       1 number=int(input("Enter a four digit number: "))
#       2
# ----> 3 total =int((number[0]) + (number[1]) + (number[2]) + (number[3]))
#       4
#       5 print(f"{number[0]}+{number[1]}+{number[2]}+{number[3]}={total}")
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# # ***LISTS***

# %%
#manually creating a list by defining it

students=["John", "Mya", "Evans"]
print(students)
print(type(students))
# Out:
# ['John', 'Mya', 'Evans']
# <class 'list'>

# %% [markdown]
# used when string does not have any defined separator.

# %%
#creating lists by type casting
name="John"
name=list(name)
print(name)
# Out:
# ['J', 'o', 'h', 'n']

# %% [markdown]
# used when you have spaces or commas between words or values in general

# %%
#creating a liat using the split method

school="soma,riverdale,strathmore"
school.split(",")
# Out:
# ['soma', 'riverdale', 'strathmore']

# %% [markdown]
# # ***ESCAPE CHARACTERS AND STRING FORMATTING***

# %% [markdown]
# STRING LITERALS

# %%
paragraph="""
this is a line
this is another line
this has a '
this has a \
"""
print(paragraph.replace("\n","\t"))
# Out:
# 	this is a line	this is another line	this has a '	this has a \
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipykernel_493/2970697320.py:5: SyntaxWarning: invalid escape sequence '\ '
#   this has a \

# %% [markdown]
# # ***BACKSLASH N***

# %%
introduction="I am John.\nMy age is 19"
print(introduction)
# Out:
# I am John.
# My age is 19

# %% [markdown]
# BACKSLASH T

# %%
introduction="\tI am John.\n\tMy age is 19"
print(introduction)
# Out:
# 	I am John.
# 	My age is 19

# %%
introduction="I am John.\n\tMy age is 19"
print(introduction)
# Out:
# I am John.
# 	My age is 19

# %%
introduction="I\'m John.\nMy age is 19"
print(introduction)
# Out:
# I'm John.
# My age is 19

# %%
print(paragraph.replace("\n","\t"))
# Out:
# 	this is a line	this is another line	this has a '	this has a \   # backslash isnt included in output because it is a syntax for escape characters

# %% [markdown]
# # ***MINI SCHOOL DATASET(CSV)***

# %%
data="""name, gender, grade

john, m, 76
jane, f, 72
joseph, m, 84
susan, f, 72
"""

# %%
rows=data.split("\n")

print(rows[0].split(","))
# Out:
# ['name', ' gender', ' grade']

# %%
data.split(",")
# Out:
# ['name',
#  ' gender',
#  ' grade\n\njohn',
#  ' m',
#  ' 76 \njane',
#  ' f',
#  ' 72 \njoseph',
#  ' m',
#  ' 84 \nsusan',
#  ' f',
#  ' 72 \n']

# %%
print(data.split("\n")[0].split(","))
# Out:
# ['name', ' gender', ' grade']

# %% [markdown]
# GENERATE HIGHEST MARK

# %%
cols=data.split("\n")[0].split(",")
print(columns)
# Out:
# ['name', ' gender', ' grade']

# %%
cols[0]
# Out:
# 'name'

# %%
cols[0:2]
# Out:
# ['name', ' gender']

# %%
cols[-1]
# Out:
# ' grade'

# %%
cols[1:3]
# Out:
# [' gender', ' grade']

# %%
cols[0:2]
# Out:
# ['name', ' gender']

# %%
cols[::-1]
# Out:
# [' grade', ' gender', 'name']

# %%
cols[-1:-3:-1]
# Out:
# [' grade', ' gender']

# %%
cols[1: ]
# Out:
# [' gender', ' grade']

# %% [markdown]
# # ***CHANGING VALUES***

# %%
cols[1]="weight"
print(cols)
# Out:
# ['name', 'weight', ' grade']

# %% [markdown]
# # ***METHODS***
# .append-adds an item to the end of a list.
# .pop-removes an item from a list.
# .pop also removes an item at the end of a lsit strictly if nothing is entered in the brackets.
# .insert-allows insertion at a given index.
# .remove-the item has to exist in the list before running since if inexistent may lead to an error.
# .extend-joins or concatenates two or more lists.
# .clear-removes all items.
# .index-gets index of an item.(returns only the index of the first occurence of an item)
# .count-checks number of occurrences of an item.
# .sort-arranges from smallest to largest.
# .reverse-reverses your  list.

# %%
cols.append("age")
print(cols)
# Out:
# ['name', 'weight', ' grade', 'age']

# %%
cols.pop(1)
print(cols)
# Out:
# ['name', ' grade', 'age']

# %%
cols.insert(1,"weight")
print(cols)
# Out:
# ['name', 'weight', ' grade', 'age']

# %%
cols.remove("weight")
print(cols)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_493/19813481.py in <cell line: 0>()
# ----> 1 cols.remove("weight")
#       2 print(cols)
#
# ValueError: list.remove(x): x not in list

# %%
if "weight" in cols:
  cols.remove("weight")
  print(cols)

# %%
cols=cols+["address","email"]
print(cols)
# Out:
# ['name', ' grade', 'age', 'address', 'email']

# %%
cols.index("weight")
cols=cols+["address","email"]
print(cols)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_493/2585201942.py in <cell line: 0>()
# ----> 1 cols.index("weight")
#       2 cols=cols+["address","email"]
#       3 print(cols)
#
# ValueError: 'weight' is not in list

# %%
cols.count("address")
# Out:
# 1

# %%
cols.index("address")
# Out:
# 3

# %%
marks=[20,54,6,45,76]
marks.sort(reverse=True)

print(marks)
# Out:
# [76, 54, 45, 20, 6]

# %%
marks=[20,54,6,45,76]
marks.sort()
marks.reverse()
print(marks)
# Out:
# [76, 54, 45, 20, 6]

# %%
marks=[20,54,6,45,76]
marks.sort()

print(marks)
# Out:
# [6, 20, 45, 54, 76]

# %% [markdown]
# # ***LIST FUNCTIONS***
# LEN()-RETURNS NUMBER OF ITEMS IN A LIST
# SUM()-SUM OF ITEMS"LIST HAS TO CONTAIN NUMERICAL VALUES"
# MIN()-LEAST ITEM
# MAX()-MAX ITEM VALUE

# %%
scores=[10,20,30]

scores.append(40)

scores.insert(1,15)

print(scores)

average=sum(scores)/len(scores)

print(f"Average is: {average}")
# Out:
# [10, 15, 20, 30, 40]
# Average is: 23.0
