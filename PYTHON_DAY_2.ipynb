# %% [markdown]
# <a href="https://colab.research.google.com/github/myaorina/DATA-SCIENCE-SC/blob/main/PYTHON_DAY_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *DAY 2:PYTHON*
# Print is a function used to give output
# Input is a function that collects input from the user:can be used to ask the user a question whcih can then be answered by the user
#    variable = input("question")*the question is always a string*
#    As long as one of the cells is running the others won't run
# You can add a space between the question mark and last quotation mark to make it neat
# Chaining means using multiple functions within the same line of code ie, number 20
# Whatever comes after a hashtag of a comment is ignored
# Values collected by input are always stored as strings whether it is a text or number
# thus whenever you are using input for numerical values you should type cast ie, age=int(input("who are you?") or age=input("who are you?") then age=int(age)
# As a data scientist there's two factors to consider: workability,how correct the code is,and navigation within the code for users
# Double equal signs are used for comparison
# Boolean will always start with a capital letter so even when coding always start with capital letters
# Always show which data type you have used ie, Age = int(input("enter your name please")
# download yescode,anaconda,pythom

# %%
name = input("What is your name? ")
# Out:
# What is your name? Zee

# %%
print(name)
# Out:
# Zee

# %%
name = "John"
type(name)
# Out:
# str

# %%
name = input("What is your name? ")
food = input("What is your favorite food? ")
sport = input("What is your favourite sport? ")

print("Hello",name+"!")
print("You like",food+".")
print("Your favourite sport is",sport+".")

print(f"Hello,{name}!")
print(f"You like,{food}.")
print(f"Your favourite sport is,{sport}.")
# Out:
# What is your name? Mya
# What is your favorite food? chapati
# What is your favourite sport? swimming
# Hello Mya!
# You like chapati.
# Your favourite sport is swimming.
# Hello,Mya!
# You like,chapati.
# Your favourite sport is,swimming.

# %% [markdown]
# **DATA** **TYPES**

# %%
x = 10
y = 3.14

# %%
#name="Johnny"
print(name)
# Out:
# Johnny

# %%
is_raining = True
is_raining = False

# %%
print (type(is_raining))
# Out:
# <class 'bool'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(3.14))
# Out:
# <class 'float'>

# %%
print (1+1)
print(10-1)
print(20/2)
print(23*3)
print(5/2)
print(5%2)
print(5**2)
# Out:
# 2
# 9
# 10.0
# 69
# 2.5
# 1
# 25

# %%
x = 12
print(type(x))
# Out:
# <class 'int'>

# %%
x = float(x)
print(type(x))
print(x)
# Out:
# <class 'float'>
# 12.0

# %%
current_body_temperature = input("What is your current body temperature? ")
print(f"Your current body temperature is {current_body_temperature}")
cbt = float(current_body_temperature)
f = (cbt*1.8)+32
print(f"your current body temperature in farenheit is {f}")
# Out:
# What is your current body temperature? 37
# Your current body temperature is 37
# your current body temperature in farenheit is 98.60000000000001

# %%
btc = input("what is your btc?")
btf = (btc*1.8)+32
print(f"Your btf is {btf}")
# Out:
# what is your btc?23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_374/4292080309.py in <cell line: 0>()
#       1 btc = input("what is your btc?")
# ----> 2 btf = (btc*1.8)+32
#       3 print(f"Your btf is {btf}")
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
print("Your body temp in f is", float("what is your body temp?")*1.8 +32"))
# Out:
#   File "/tmp/ipykernel_374/3962450244.py", line 1
#     print("Your body temp in f is", float("what is your body temp?")*1.8 +32"))
#                                                                             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# ***MINI*** ***CALCULATOR***

# %%
fn = input("First number? ")
sn = input("Second number? ")

f = float(fn) #first number
s = float(sn) #second number

print(f"The sum is {f + s}"+".")
print(f"The mutiple is {f*s}"+".")
print(f"The quotient is {f//s}"+".")
print(f"The difference is {f-s}"+".")
print(f"The quotient is {f/s}"+".")
print(f"The remainder is {f%s}"+".")
print(f"The exponential is {f**s}"+".")
# Out:
# First number? 14
# Second number? 3
# The sum is 17.0.
# The mutiple is 42.0.
# The quotient is 4.0.
# The difference is 11.0.
# The quotient is 4.666666666666667.
# The remainder is 2.0.
# The exponential is 2744.0.

# %%
print(20>10)
print(20<10)
# Out:
# True
# False

# %%
print(20<10)
# Out:
# False

# %%
print(5==5)
# Out:
# True

# %%
print(5!=5)
# Out:
# False

# %%
#names = input("What is your name?")
#age = input("what is your age?")
#course = input("what course are you doing?")

print("==================")
print("STUDENT PROFILE")
print("==================")
print("Name:",names)
print("Age:",20)
print("course",course)
# Out:
# ...
# STUDENT PROFILE
# ...
# Name: Mya
# Age: 20
# course CDAV

# %%
name = input("product?")
price = input("price?")
quantity = input("how many?")

price_1=float(price)
quantity_1=int(quantity)

total= price_1 * quantity_1

print("The total is ksh.",total)
# Out:
# product?80
# price?60
# how many?5
# The total is ksh. 300.0

# %%
weight = input("What is your weight in kgs?")
height = input("What is your height in metres?")

weight_1 = float(weight)
height_1 = float(height)

bmi = weight_1/height_1
print("The bmi is",bmi)
# Out:
# What is your weight in kgs?80
# What is your height in metres?9
# The bmi is 8.88888888888889
