# %% [markdown]
# <a href="https://colab.research.google.com/github/myaorina/DATA-SCIENCE-SC/blob/main/DAY_7_MORNING_TASKS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***TUPLES***
#
# tuples are a collection of unique values while for lists the values ca n be repeated.
# tuples are mutable and unordered.
# both tuples and lists allow mixed data types.
# tuple has curved brackets and are separated by commas
# a set has curly brackets and is also separated by commas
# since curved brackets are usually used for a lot of operations,when having a single item tuple,a coma is added after a string to show python that it is dealing with a tuple.ie, name=("John",) of which if coma is excluded,the output will be a string.
# Tuples are unchangeable,when created they remain constant.
# Tuples are usually used in cases where you dont expect items to change.
# Tuples are usually used for mass assignment.
# Sets dont have indices so you cant insert.
# for tuples you can use count and index methods
# for sets you can use add,remove,discard methods.if the item already exists it cannot be added.
#
# the difference between remove and discard is that for remove the item has to be in existence while for discard the item if not in existence,will not lead to an error
# discard is more efficient as is flexible
# for sets count doesnt matter cause items exist only once therefore having count would be unnecessary.

# %% [markdown]
# Create a program that reads integers from the user until a blank line is entered. Once all of the integers have been read your program should display all of the negative numbers, followed by all of the zeros, followed by all of the positive numbers.
# Within each group the numbers should be displayed in the same order that they were entered by the user.
# For example, if the user enters the values 3, -4, 1, 0, -1, 0, and -2 then your program should output the values -4, -1, -2, 0, 0, 3, and 1.
# Your program should display each value on its own line.

# %%
numbers = []

while True:
    value = input("Enter an integer: ")

    if value == "":
        break
    value = int(value)
    numbers.append(value)

for number in numbers:
    if number < 0:
        print(number)

for number in numbers:
    if number == 0:
        print(number)

for number in numbers:
    if number > 0:
        print(number)
# Out:
# Enter an integer: 5
# Enter an integer: 0
# Enter an integer: 8
# Enter an integer: -5
# Enter an integer: -2
# Enter an integer: 1
# Enter an integer:
# -5
# -2
# 0
# 5
# 8
# 1

# %% [markdown]
# In this exercise, you will create a program that reads words from the user until the
# user enters a blank line. After the user enters a blank line your program should display each word entered by the user exactly once. The words should be displayed in
# the same order that they were entered. For example, if the user enters:
# first
# second
# first
# third
# second
# then your program should display:
# first
# second
# third

# %%
while True:
    words = input("Enter a word: ")
    if word == "":

for word in words:
    print(word)
# Out:
#   File "/tmp/ipykernel_1192/2898654972.py", line 5
#     for word in words:
#                       ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
rgb_colour=(101,200,25)
print(type(rgb_colour))
print(rgb_colour)
# Out:
# <class 'tuple'>
# (101, 200, 25)

# %%
pi_val = (3.14)
pi_tup = (3.14,)
print(type(pi_val))
print(type(pi_tup))
# Out:
# <class 'float'>
# <class 'tuple'>

# %%
pi_val=3.2

# %%
pi_tup[0]=3.2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1192/1330120232.py in <cell line: 0>()
# ----> 1 pi_tup[0]=3.2
#
# TypeError: 'tuple' object does not support item assignment

# %%
names_tup=("John","Mary","Shawn","Shawn","Peter")
print(names_tup.index("Mary"))
print(names_tup.count("Shawn"))
# Out:
# 1
# 2

# %%
a,b=(10,11)
print(b)
# Out:
# 11

# %%
for name in names_tup:
  print(name.upper())
# Out:
# JOHN
# MARY
# SHAWN
# SHAWN
# PETER

# %%
print([name.upper() for name in names_tup])
# Out:
# ['JOHN', 'MARY', 'SHAWN', 'SHAWN', 'PETER']

# %% [markdown]
# # ***SETS***

# %%
fruits=["apple","mango","apple","mango","banana"]
print(fruits)
# Out:
# ['apple', 'mango', 'apple', 'mango', 'banana']

# %%
fruits_set=["apple","mango","apple","mango","banana"]
print(fruits_set)
# Out:
# ['apple', 'mango', 'apple', 'mango', 'banana']

# %%
fruits_set2=set(fruits)
print(fruits_set2)
# Out:
# {'banana', 'mango', 'apple'}

# %%
fruits_set_upper={fruit.upper() for fruit in fruits}
print(fruits_set_upper)
# Out:
# {'APPLE', 'BANANA', 'MANGO'}

# %%
fruits_set.add("plum")
print(fruits_set)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1192/32812667.py in <cell line: 0>()
# ----> 1 fruits_set.add("plum")
#       2 print(fruits_set)
#
# AttributeError: 'list' object has no attribute 'add'

# %%
fruits_set.remove("kiwi")
print(fruits_set)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1192/3080894518.py in <cell line: 0>()
# ----> 1 fruits_set.remove("kiwi")
#       2 print(fruits_set)
#
# ValueError: list.remove(x): x not in list

# %%
fruits_set.discard("kiwi")
print(fruits_set)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1192/1972030707.py in <cell line: 0>()
# ----> 1 fruits_set.discard("kiwi")
#       2 print(fruits_set)
#
# AttributeError: 'list' object has no attribute 'discard'

# %% [markdown]
# # ***DICTIONARIES***
# Use curly brackets
# has a key and a value,differentiating it from sets
# they are mutable
# the key can be a string,integer or tuple
# use delete to delete a key value
# the key has to be a mutable value
#
# .update({})-adds or updates values
# .get(key,data....... )-gets a value
# .pop(key)-removes an item
# .keys()-returns a list of all labels
# .values()-returns a list of all data values

# %%
student_grades= {
    "math":80,
    "english":95,
    "cre":92
    }

print(type(student_grades))
# Out:
# <class 'dict'>

# %%
student_grades["math"]
# Out:
# 80

# %%
math_results=student_grades["math"]
print(math_results)
# Out:
# 80

# %%
student_grades["physics"]=78
print(student_grades)
# Out:
# {'math': 80, 'english': 95, 'cre': 92, 'physics': 78}

# %%
student_grades["math"]=82
print(student_grades)

del student_grades["math"]
print(student_grades)
# Out:
# {'english': 95, 'cre': 92, 'physics': 78, 'math': 82}
# {'english': 95, 'cre': 92, 'physics': 78}

# %%
del student_grades["cre"]
print(student_grades)
# Out:
# {'math': 80, 'english': 95, 'physics': 78}

# %%
student_grades= {
    "math":80,
    "english":95,
    "cre":92
    }
student_grades["math"]=80
student_grades["english"]=95
student_grades["physics"]=78

# %%
student_grades.update({"math":70, "english":100})
print(student_grades)
# Out:
# {'math': 70, 'english': 100, 'physics': 78}

# %%
print(student_grades["math"])
# Out:
# 70

# %%
print(student_grades.get("math"))
# Out:
# 70

# %%
print(student_grades.get("math,0"))
# Out:
# None

# %%
student_grades.pop("math",0)
# Out:
# 70

# %%
student_grades
# Out:
# {'english': 100, 'physics': 78}

# %%
for key in student_grades.keys():
  print(key.upper())
# Out:
# ENGLISH
# PHYSICS

# %%
for val in student_grades.values():
  print(val)
# Out:
# 100
# 78

# %%
for item in student_grades.items():
  print(item)
# Out:
# ('english', 100)
# ('physics', 78)

# %%
for key,val in student_grades.items():
  print(key,"contains",val)
# Out:
# english contains 100
# physics contains 78
